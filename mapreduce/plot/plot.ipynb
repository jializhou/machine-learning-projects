# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from matplotlib.collections import PatchCollection
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon
from shapely.prepared import prep
from pysal.esda.mapclassify import Natural_Breaks as nb
from descartes import PolygonPatch
import fiona
from itertools import chain
import pysal.esda.mapclassify as mapclassify
 
r = fiona.open('nynta_15c/nynta.shp')

bds = r.bounds

# %%
extra = 0.1

#define the lower left hand boundary (longitude, latitude)
ll = (bds[0], bds[1])

#define the upper right hand boundary (longitude, latitude)
ur = (bds[2], bds[3])

#concatenate the lower left and upper right into a variable called coordinates
coords = list(chain(ll, ur))
print coords
# Out:
# [913175.1090087891, 120121.8812536771, 1067382.5085923828, 272844.2938232422]

# %%
#define a variable called extra which we will use for padding the map when we display it (in this case I've selected a 10% pad)
extra = 0.1

#define the lower left hand boundary (longitude, latitude)
ll = (bds[0], bds[1])

#define the upper right hand boundary (longitude, latitude)
ur = (bds[2], bds[3])

#concatenate the lower left and upper right into a variable called coordinates
coords = list(chain(ll, ur))

#define variables for the width and the height of the map
w, h = coords[2] - coords[0], coords[3] - coords[1]


m = Basemap(
    #set projection to 'tmerc' which is apparently less distorting when close-in
    projection='tmerc',

    #set longitude as average of lower, upper longitude bounds
    lon_0 = np.average([bds[0],bds[2]]),

    #set latitude as average of lower,upper latitude bounds
    lat_0 = np.average([bds[1],bds[3]]),

    ellps = 'WGS84',
    
    #set the map boundaries. Note that we use the extra variable to provide a 10% buffer around the map
    llcrnrlon=coords[0] - extra * w,
    llcrnrlat=coords[1] - extra + 0.01 * h,
    urcrnrlon=coords[2] + extra * w,
    urcrnrlat=coords[3] + extra + 0.01 * h,

    #provide latitude of 'true scale.' Not sure what this means, I would check the Basemap API if you are a GIS guru
    lat_ts=0,

    #resolution of boundary database to use. Can be c (crude), l (low), i (intermediate), h (high), f (full) or None.
    resolution='i',
    
    #don't show the axis ticks automatically
    suppress_ticks=True)

m.readshapefile(
    #provide the path to the shapefile, but leave off the .shp extension
    'nynta_15c/nynta',

    #name your map something useful (I named this 'srilanka')
    'NY',

    #set the default shape boundary coloring (default is black) and the zorder (layer order)
    color='none',
    zorder=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7cc085f440a9> in <module>()
#      40
#      41     #don't show the axis ticks automatically
# ---> 42     suppress_ticks=True)
#      43
#      44 m.readshapefile(
#
# /Users/baymax/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in __init__(self, llcrnrlon, llcrnrlat, urcrnrlon, urcrnrlat, llcrnrx, llcrnry, urcrnrx, urcrnry, width, height, projection, resolution, area_thresh, rsphere, ellps, lat_ts, lat_1, lat_2, lat_0, lon_0, lon_1, lon_2, o_lon_p, o_lat_p, k_0, no_rot, suppress_ticks, satellite_height, boundinglat, fix_aspect, anchor, celestial, round, epsg, ax)
#     670         projparams['units']='m'
#     671         # check for sane values of lon_0, lat_0, lat_ts, lat_1, lat_2
# --> 672         _insert_validated(projparams, lat_0, 'lat_0', -90, 90)
#     673         _insert_validated(projparams, lat_1, 'lat_1', -90, 90)
#     674         _insert_validated(projparams, lat_2, 'lat_2', -90, 90)
#
# /Users/baymax/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in _insert_validated(d, param, name, minval, maxval)
#     504 def _insert_validated(d, param, name, minval, maxval):
#     505     if param is not None:
# --> 506         d[name] = _validated_ll(param, name, minval, maxval)
#     507
#     508 def _transform(plotfunc):
#
# /Users/baymax/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in _validated_ll(param, name, minval, maxval)
#     499     if param > maxval or param < minval:
#     500         raise ValueError('%s must be between %f and %f degrees' %
# --> 501                                            (name, minval, maxval))
#     502     return param
#     503
#
# ValueError: lat_0 must be between -90.000000 and 90.000000 degrees

# %%
len(m.NY)
# Out:
# 858897

# %%
len(m.NY[1])
# Out:
# 15

# %%
m.NY_info[100]
# Out:
# {'FID': 100, 'RINGNUM': 1, 'SHAPENUM': 101}

# %%
import mpl_toolkits.basemap.pyproj as pyproj
wgs84=pyproj.Proj("+init=EPSG:4326")
epsg28992=pyproj.Proj("+init=EPSG:28992")

df_map = pd.DataFrame({

    #access the x,y coords and define a polygon for each item in m.srilanka
    'poly': [Polygon(xy) for xy in m.NY],
    #conver NAME_1 to a column called 'district'
    'city':[district['CITY'] for district in m.NY_info],
    'district': [district['COUNTY'] for district in m.NY_info]})

#add the polygon area
df_map['area_m'] = df_map['poly'].map(lambda x: x.area/1000)

#convert meters to miles
df_map['area_miles'] = df_map['area_m'] * 0.000621371
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-a7fc0c97a7d8> in <module>()
#       8     'poly': [Polygon(xy) for xy in m.NY],
#       9     #conver NAME_1 to a column called 'district'
# ---> 10     'city':[district['CITY'] for district in m.NY_info],
#      11     'district': [district['COUNTY'] for district in m.NY_info]})
#      12
#
# KeyError: 'CITY'

# %%
df_map
# Out:
#                             city  district  \
# 0                      Rochester    Monroe
# 1        New York City-Manhattan  New York
# 2         New York City-Brooklyn     Kings
# 3                        Buffalo      Erie
# 4        New York City-Manhattan  New York
# 5                         Albany    Albany
# 6                       Syracuse  Onondaga
# 7           New York City-Queens    Queens
# 8    New York City-Staten Island  Richmond
# 9                       Syracuse  Onondaga
# 10                      Syracuse  Onondaga
# 11                       Buffalo      Erie
# 12                       Buffalo      Erie
# 13       New York City-Manhattan  New York
# 14                     Rochester    Monroe
# 15           New York City-Bronx     Bronx
# 16       New York City-Manhattan  New York
# 17          New York City-Queens    Queens
# 18          New York City-Queens    Queens
# 19          New York City-Queens    Queens
# 20          New York City-Queens    Queens
# 21                       Buffalo      Erie
# 22   New York City-Staten Island  Richmond
# 23                        Albany    Albany
# 24   New York City-Staten Island  Richmond
# 25                       Buffalo      Erie
# 26                     Rochester    Monroe
# 27          New York City-Queens    Queens
# 28          New York City-Queens    Queens
# 29           New York City-Bronx     Bronx
# ..                           ...       ...
# 271          New York City-Bronx     Bronx
# 272         New York City-Queens    Queens
# 273         New York City-Queens    Queens
# 274  New York City-Staten Island  Richmond
# 275                     Syracuse  Onondaga
# 276                      Buffalo      Erie
# 277         New York City-Queens    Queens
# 278          New York City-Bronx     Bronx
# 279         New York City-Queens    Queens
# 280         New York City-Queens    Queens
# 281         New York City-Queens    Queens
# 282  New York City-Staten Island  Richmond
# 283                    Rochester    Monroe
# 284          New York City-Bronx     Bronx
# 285      New York City-Manhattan  New York
# 286      New York City-Manhattan  New York
# 287                      Buffalo      Erie
# 288                      Buffalo      Erie
# 289                      Buffalo      Erie
# 290                      Buffalo      Erie
# 291                      Buffalo      Erie
# 292  New York City-Staten Island  Richmond
# 293                       Albany    Albany
# 294                       Albany    Albany
# 295                       Albany    Albany
# 296                      Buffalo      Erie
# 297                     Syracuse  Onondaga
# 298                    Rochester    Monroe
# 299         New York City-Queens    Queens
# 300                      Buffalo      Erie
#
#                                                   poly        area_m  \
# 0    POLYGON ((159282.4210634992 296758.9120671649,...   1405.834498
# 1    POLYGON ((459092.4867172883 31863.16597889242,...   1046.240053
# 2    POLYGON ((458809.6673157916 17771.28283208245,...   5837.124695
# 3    POLYGON ((58955.04656768087 267459.2328870883,...   5343.601044
# 4    POLYGON ((461332.7814764013 32345.55183275655,...   1634.675932
# 5    POLYGON ((472639.4542274683 246380.497491956, ...    255.262919
# 6    POLYGON ((283607.9361610551 286469.351636453, ...   3898.783830
# 7    POLYGON ((476798.0989768259 33223.95824635457,...   6348.460526
# 8    POLYGON ((455464.77004392 18135.66123074645, 4...     48.624521
# 9    POLYGON ((278586.0443781414 287188.7620481158,...   1231.482830
# 10   POLYGON ((283605.4442421348 287683.7196190524,...   2897.866514
# 11   POLYGON ((58398.84747098232 279997.15809955, 5...   1961.776007
# 12   POLYGON ((57429.21317267627 275411.5267143167,...    427.985739
# 13   POLYGON ((459254.5250504777 30715.04217324252,...    490.952827
# 14   POLYGON ((157974.5798464334 307972.222271572, ...   7109.331284
# 15   POLYGON ((473314.6057470057 43115.15623930776,...   8287.661271
# 16   POLYGON ((464240.3031931437 38228.70129564295,...    387.127618
# 17   POLYGON ((473488.4573708005 39567.76358636661,...     15.893336
# 18   POLYGON ((472486.7958860336 38733.36861498666,...     15.339371
# 19   POLYGON ((472215.1306782836 38548.46371097368,...      5.270661
# 20   POLYGON ((472009.7649086439 38360.92455045896,...     13.998522
# 21   POLYGON ((58265.11726128429 277977.8471898998,...   2048.352669
# 22   POLYGON ((446302.5706765613 19450.93368129333,...   6118.753414
# 23   POLYGON ((471100.9043309582 247682.4622501691,...    230.453367
# 24   POLYGON ((440777.8273094357 11689.7419549351, ...   4409.421652
# 25   POLYGON ((57422.65163178407 270062.9722932909,...   1999.992982
# 26   POLYGON ((160348.573760704 299278.1285105128, ...   2039.696364
# 27   POLYGON ((480862.6223565642 36488.7917748617, ...  17562.005082
# 28   POLYGON ((483153.8505821113 31568.37497748501,...   7448.906192
# 29   POLYGON ((470090.7481203033 44115.01490239715,...   3441.937248
# ..                                                 ...           ...
# 271  POLYGON ((467391.2813043585 44758.91208073104,...   4614.557783
# 272  POLYGON ((473241.7951963078 22747.21784300025,...     38.134728
# 273  POLYGON ((472358.8466315898 23706.28317779012,...     13.774282
# 274  POLYGON ((452310.7926535738 18420.97710097054,...   5455.718952
# 275  POLYGON ((279832.2656973064 281709.4418278781,...   5881.313062
# 276  POLYGON ((58142.66842104864 272131.7839822257,...    963.352077
# 277  POLYGON ((474990.5733463329 30779.36702817453,...  10709.086907
# 278  POLYGON ((470729.8774391455 44592.13592399708,...   5111.258744
# 279  POLYGON ((478507.7217621278 39614.41424083688,...     33.654522
# 280  POLYGON ((478406.1785156957 39171.49141521781,...      3.012951
# 281  POLYGON ((477729.9281606292 39031.66083729541,...     10.674805
# 282  POLYGON ((449581.8858673215 17041.16479177444,...   6336.850701
# 283  POLYGON ((153502.2382648605 302319.07681538, 1...   5472.521375
# 284  POLYGON ((466264.3115772164 42190.09726082905,...   8009.801160
# 285  POLYGON ((460616.2323391619 34119.24488426646,...    802.827963
# 286  POLYGON ((465771.9252461217 39065.60581356889,...   1756.242445
# 287  POLYGON ((57360.90032462744 273156.3260812216,...   2235.914542
# 288  POLYGON ((53070.90752253131 277991.6022027055,...   3000.427163
# 289  POLYGON ((56394.01132015526 278427.940617947, ...   1276.477067
# 290  POLYGON ((61957.37929970885 277054.2609126404,...   2215.722424
# 291  POLYGON ((55950.18668760249 273010.1512811203,...    867.587550
# 292  POLYGON ((449975.375979763 20185.62024343619, ...   6986.807435
# 293  POLYGON ((470962.4667079081 248689.456600304, ...    657.617722
# 294  POLYGON ((470050.3828062781 245402.0064970262,...   1210.479129
# 295  POLYGON ((474101.5449123866 245123.1922040632,...    188.934952
# 296  POLYGON ((56574.24281629434 275248.5506596591,...   1280.530323
# 297  POLYGON ((281194.5281497553 285361.8674873402,...   2250.414382
# 298  POLYGON ((160598.4287223771 300012.9196896628,...    810.299342
# 299  POLYGON ((471252.6038308672 36622.47101160085,...    146.825532
# 300  POLYGON ((60115.7432480602 276790.2572507061, ...   2885.704336
#
#      area_miles
# 0      0.873545
# 1      0.650103
# 2      3.627020
# 3      3.320359
# 4      1.015740
# 5      0.158613
# 6      2.422591
# 7      3.944749
# 8      0.030214
# 9      0.765208
# 10     1.800650
# 11     1.218991
# 12     0.265938
# 13     0.305064
# 14     4.417532
# 15     5.149712
# 16     0.240550
# 17     0.009876
# 18     0.009531
# 19     0.003275
# 20     0.008698
# 21     1.272787
# 22     3.802016
# 23     0.143197
# 24     2.739887
# 25     1.242738
# 26     1.267408
# 27    10.912521
# 28     4.628534
# 29     2.138720
# ..          ...
# 271    2.867352
# 272    0.023696
# 273    0.008559
# 274    3.390026
# 275    3.654477
# 276    0.598599
# 277    6.654316
# 278    3.175988
# 279    0.020912
# 280    0.001872
# 281    0.006633
# 282    3.937535
# 283    3.400466
# 284    4.977058
# 285    0.498854
# 286    1.091278
# 287    1.389332
# 288    1.864378
# 289    0.793166
# 290    1.376786
# 291    0.539094
# 292    4.341400
# 293    0.408625
# 294    0.752157
# 295    0.117399
# 296    0.795684
# 297    1.398342
# 298    0.503497
# 299    0.091233
# 300    1.793093
#
# [301 rows x 5 columns]

# %%
# %matplotlib inline 
import os
import mpl_toolkits.basemap.pyproj as pyproj
def read_txt(path):
	frames = pd.DataFrame()
	for file in os.listdir(path):
	    if file.endswith(".csv"):	    	
	    	file = os.path.join(path,file)
	        frames = frames.append(pd.read_csv(file, sep = ','))
	return frames

df = read_txt('./uber-2014')

# %%
# Out:
# (1438623.2065072248, -8457908.995077644)

# %%
# Convenience functions for working with color ramps and bars
def colorbar_index(ncolors, cmap, labels=None, **kwargs):
    """
    This is a convenience function to stop you making off-by-one errors
    Takes a standard colour ramp, and discretizes it,
    then draws a colour bar with correctly aligned labels
    """
    cmap = cmap_discretize(cmap, ncolors)
    mappable = cm.ScalarMappable(cmap=cmap)
    mappable.set_array([])
    mappable.set_clim(-0.5, ncolors+0.5)
    colorbar = plt.colorbar(mappable, **kwargs)
    colorbar.set_ticks(np.linspace(0, ncolors, ncolors))
    colorbar.set_ticklabels(range(ncolors))
    if labels:
        colorbar.set_ticklabels(labels)
    return colorbar

def cmap_discretize(cmap, N):
    """
    Return a discrete colormap from the continuous colormap cmap.

        cmap: colormap instance, eg. cm.jet. 
        N: number of colors.

    Example
        x = resize(arange(100), (5,100))
        djet = cmap_discretize(cm.jet, 5)
        imshow(x, cmap=djet)

    """
    if type(cmap) == str:
        cmap = get_cmap(cmap)
    colors_i = np.concatenate((np.linspace(0, 1., N), (0., 0., 0., 0.)))
    colors_rgba = cmap(colors_i)
    indices = np.linspace(0, 1., N + 1)
    cdict = {}
    for ki, key in enumerate(('red', 'green', 'blue')):
        cdict[key] = [(indices[i], colors_rgba[i - 1, ki], colors_rgba[i, ki]) for i in xrange(N + 1)]
    return matplotlib.colors.LinearSegmentedColormap(cmap.name + "_%d" % N, cdict, 1024)

# %%
jenks = False
var_2_analyze = 'area_m'
if jenks == True:
    # Calculate Jenks natural breaks for each polygon
    breaks = nb(
        # set the data to use
        df_map[df_map[var_2_analyze].notnull()][var_2_analyze].values,

        # since this is an optimization function we need to give it a number of initial solutions to find. 
        # you can adjust this number if you are unsatisfied with the bin results
        initial=300,

        # k is the number of natural breaks you would like to apply. I've set it to 10, but you can change.
        k=10)

else:
    # Define my own breaks [even split each 20 percentage points] Note that the bins are the top range so >20, >40, etc
    # you can change the bins to whatever you like, though they should be based on the data you are analyzing
    # since I am going to plot data on a 0 to 100 scale, I chose these break points
    my_bins = [20,40,60,80,100]
    
    # Calculate the user defined breaks for our defined bins
    breaks = mapclassify.User_Defined(
               
            # set the data to use 
            df_map[df_map[var_2_analyze].notnull()][var_2_analyze].values, 
            
            #use my bins
            my_bins)

# %%
# check if this is a jenks or user-defined break
if jenks == True:
    
    # if jenks, use these labels
    bin_labels = ["<= %0.0f" % b for b in breaks.bins]
else: 
    
    # if user defined, use these ones
    bin_labels = ["< %0.0f" % b for b in breaks.bins]
    
print 'Here are the bin labels:'
for label in bin_labels:
    print label
# %matplotlib inline
# Out:
# Here are the bin labels:
# < 20
# < 40
# < 60
# < 80
# < 100
# < 28002

# %%
# initialize the plot
plt.clf()

# define the figure and set the facecolor (e.g. background) to white
fig = plt.figure(facecolor='white')

# ad a subplot called 'ax'
ax = fig.add_subplot(111, axisbg='w', frame_on=False)

# use a blue colour ramp ('Blues') - we'll be converting it to a map using cmap()
# you could also use 'Oranges' or 'Greens' 
cmap = plt.get_cmap('Blues')


# draw district with grey outlines
df_map['patches'] = df_map['poly'].map(lambda x: PolygonPatch(x, ec='#555555', lw=.2, alpha=1., zorder=4))


# set the PatchCollection with our defined 'patches'
pc = PatchCollection(df_map['patches'], match_original=True)

# normalize our bins between the min and max values within the bins
norm = Normalize(vmin=df_map['area_m'].min(), vmax=df_map['area_m'].max())

# impose our color map onto the patch collection
pc.set_facecolor(cmap(norm(df_map['area_m'].values)))
ax.add_collection(pc)

# Add a color bar which has our bin_labels applied
cb = colorbar_index(ncolors=len(bin_labels), cmap=cmap, shrink=0.5, labels=bin_labels)
# set the font size of the labels (set to size 10 here)
cb.ax.tick_params(labelsize=10)

# Create a bit of small print
smallprint = ax.text(
    # set the x,y location of the smallprint
    1, 1,
    # add whatever text you would like to appear
    'This is a map of new york showing ' + var_2_analyze + ' per district.',
    # set the horizontal/vertical alignment
    ha='right', va='bottom',
    # set the size and the color
    size=10,
    color='#555555',
    transform=ax.transAxes)

# Draw a map scale
m.drawmapscale(
    #set the coordinates where the scale should appear
    coords[0] + 0.08, coords[1] + 0.215,
    coords[0], coords[1],
    # what is the max value of the scale (here it's set to 25 for 25 miles)
    25.,
    barstyle='fancy', labelstyle='simple',
    fillcolor1='w', fillcolor2='#555555',
    fontcolor='#555555',
    zorder=5,
    # what units would you like to use. Defaults to km
    units='mi')

# set the layout to maximally fit the bounding area
plt.tight_layout()

# define the size of the figure
fig.set_size_inches(5,6)

# save the figure. Increase the dpi to increase the quality of the output .png. For example, dpi=1000 is super high quality
# note that the figure will be saved as 'sri_lanka_' then the name of the variable under analysis
# you can change this to whatever you want
plt.savefig('sri_lanka_' + var_2_analyze + '.png', dpi=100, alpha=True)

# display our plot
plt.show()
